# %% [markdown]
# # Read Files into Python

# %% [markdown]
# ## Read Text Files

# %%
jmu_news = open('jmu_news.txt','r')

news_content = jmu_news.read()

print(news_content)

# %% [markdown]
# use with as statement

# %%
with open('jmu_news.txt','r') as jmu_news:
    print(jmu_news.read())

# %% [markdown]
# try Counter

# %%
from collections import Counter

count_result = Counter(['a','a','a','b','b','c'])

for word,count in count_result.most_common(2):
    print(word,count)

# %% [markdown]
# find the top 10 words

# %%
with open('jmu_news.txt','r') as jmu_news:
    
    news_content = jmu_news.read() #load the news
    
    word_list = news_content.split() # split the news into words
    
    count_result = Counter(word_list) # Counter the words in the list
    
    for word, count in count_result.most_common(10):
        print(word,count)

# %% [markdown]
# list generator

# %%
num_list = [1,2,3,4]

new_list = [  num+1  for num in num_list ]

print(new_list)

# %%
convert all the words of jmu news to lower cases

# %%
with open('jmu_news.txt','r') as jmu_news:
    
    news_content = jmu_news.read()
    
    word_list = news_content.split()
    
    low_case_list = [ word.lower()   for word in word_list  ]
    
    print(low_case_list)

# %% [markdown]
# try string format

# %%
print("{1}'s income is ${0}.".format(70000,'Tom'))

# %% [markdown]
# ## read json file

# %%
import json
from pprint import pprint

# %%
with open('demo.json','r') as json_file:
    
    json_dict = json.load(json_file)
    
    pprint(json_dict['id']) # get the url
    pprint(json_dict['share']['share_count']) #get nested value

# %% [markdown]
# ## read data from websites

# %%
import urllib.request

# %%
url = 'http://www.jmu.edu'

response = urllib.request.urlopen(url)

web_content = response.read()

print(web_content.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>James Madison University - JMU</title>
#
#
#
#
#
#
# <meta property="og:title" content='JMU' />
# <meta property="og:description" content='JMU' />
# <meta property="og:image" content="//www.jmu.edu/_images/default/JMUopengraphimage.jpg" />
# <meta property="og:url" content="https://www.jmu.edu/index.shtml" />
# <meta name="twitter:card" content="summary_large_image"/>
# <meta name="twitter:title" content="JMU"/>
# <meta name="twitter:description" content="JMU"/>
# <meta name="twitter:image" content="https://www.jmu.edu/_images/default/JMUopengraphimage.jpg" />
#
# <!--start extended header--><!--end extended header-->
# ...
